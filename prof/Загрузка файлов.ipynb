# %% [markdown]
# # Таблицы csv, txt pandas

# %%
import pandas as pd

# csv
df_csv = pd.read_csv('data.csv')
df_csv_delim = pd.read_csv('data.txt', delimiter='\t')  # табуляция

# с параметрами
df = pd.read_csv('data.csv', 
                 sep=',',           # разделитель
                 encoding='utf-8',  # кодировка
                 header=0,          # строка заголовков
                 skiprows=1)        # пропустить строки

# %% [markdown]
# # TXT как файл

# %%
# весь файл
with open('data.txt', 'r', encoding='utf-8') as file:
    contect = file.read()
# построчно
with open('data.txt', 'r', encoding='utf-8') as file:
    lines = file.readlines()

# для больших файлов
with open('data.txt', 'r', encoding='utf-8') as file:
    for line in file:
        process(line)

# %% [markdown]
# # Картинки

# %%
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# с помощью PIL
img_pil = Image.open('image.jpg')

# с помощью OpenCV
img_cv2 = cv2.imread('image.jpg')
img_cv2_rgb = cv2.cvtColor(img_cv2, cv2.COLOR_BGR2RGB)  # конвертация в RGB

# с помощью matplotlib
img_plt = mpimg.imread('image.jpg')

# с помощью scikit-image
from skimage import io
img_sk = io.imread('image.jpg')

# %% [markdown]
# # JSON - Pandas, module JSON

# %%
import pandas as pd
import json

#  через pandas
df_json = pd.read_json('data.json')

# Для JSON Lines (каждая строка - JSON объект)
df_jsonl = pd.read_json('data.jsonl', lines=True)

# через модуль json
with open('data.json', 'r', encoding='utf-8') as file:
    data = json.load(file)  # для объекта JSON
    # или
    # data = json.loads(file.read())

# Для больших JSON файлов построчно
data_list = []
with open('data.json', 'r', encoding='utf-8') as file:
    for line in file:
        data_list.append(json.loads(line))

# %% [markdown]
# # DB

# %%
import pandas as pd
import sqlite3
import psycopg2
from sqlalchemy import create_engine

# pandas read_sql (требуется соединение)
connection = sqlite3.connect('database.db')
df_sql = pd.read_sql('SELECT * FROM table_name', connection)
connection.close()

#  через SQLAlchemy engine
engine = create_engine('postgresql://user:password@localhost/dbname')
df = pd.read_sql('SELECT * FROM table_name', engine)

# через курсор (для детального управления)
conn = psycopg2.connect(
    host="localhost",
    database="dbname",
    user="user",
    password="password"
)
cursor = conn.cursor()
cursor.execute("SELECT * FROM table_name")
rows = cursor.fetchall()
# Получение названий колонок
column_names = [desc[0] for desc in cursor.description]
cursor.close()
conn.close()

# %% [markdown]
# # Доп: excel

# %%
import pandas as pd

# Чтение Excel
df_excel = pd.read_excel('data.xlsx', sheet_name='Sheet1')

# Чтение нескольких листов
excel_data = pd.read_excel('data.xlsx', sheet_name=None)  # словарь DataFrame
df1 = excel_data['Sheet1']
df2 = excel_data['Sheet2']
